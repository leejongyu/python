# %% [markdown]
# # else가 없는 조건문
# ```
# if 조건식:
#     조건식이 참일 때 실행할 코드 (블록)
#
# ```
#
# * `if 조건식` 뒤에는 반드시 콜론(:)을 사용해야 함.
# * `if` 블록(조건식이 참일 때 실행할 문장들)은 반드시 __같은 크기__로 들여쓰기(indentation)를 해야 함.

# %%
n = 100

# %%
if n > 0:
    print('양수')
    print('if 블록 끝')

print('if 바깥')
# Out:
# 양수
# if 블록 끝
# if 바깥

# %% [markdown]
# # else가 있는 조건문
# ```
# if 조건식:
#     조건식이 참일 때 실행할 코드 블록
# else:
#     조건식이 거짓일 때 실행할 코드 블록
# ```

# %%
n = int(input('정수 입력 :'))

if n%2: #정수 n을 나눈 나머지가 있으면 
    print('홀수')
else: #없으면
    print('짝수')
# Out:
# 정수 입력 :51
# 홀수

# %% [markdown]
# ##Python에서 참(True)으로 취급하는 것들 ⁉
# * 0이 아닌 숫자들
# * 1개 이상의 글자를 가지고 있는 문자열
# * 1개 이상의 원소를 가지고 있는 배열,리스트 ...

# %% [markdown]
# # Chained Conditional
# ```
# if 조건식1:
#     조건식1이 참일 때 실행할 코드 블록
# elif 조건식2:
#     조건식1이 거짓이고, 조건식2가 참일 때 실행할 코드 블록
# ...
# else:
#     위의 모든 조건식들을 만족하지 못할 때 실행할 코드 블록
# ```

# %%
x = int(input('점수 입력 : '))
y = int(input('점수 입력 : '))
z = int(input('점수 입력 : '))


a = (x+y+z)/3

print(f'평균 = {a}')

if a >= 90 :
    print('A')
elif 80 <= a < 90 :
    print('B')
elif 70 <= a < 80 :
    print('C')
else:
    print('F')
# Out:
# 점수 입력 : 80
# 점수 입력 : 40
# 점수 입력 : 20
# 평균 = 46.666666666666664
# F
